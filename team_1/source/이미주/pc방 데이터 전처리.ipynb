# %%
import pandas as pd
pcdata = pd.read_excel('/content/sample_data/PC방전처리.xlsx')
# Out:
# <ipython-input-28-464ee4c85214>:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pcdata = pd.read_excel('/content/sample_data/PC방전처리.xlsx')

# %%
pcdata
# Out:
#       Unnamed: 0      인허가일자       폐업일자           영업상태명  \
# 0              0 2020-11-06 2020-01-01           영업/정상
# 1              1 2019-05-20 2020-01-01           영업/정상
# 2              2 2017-05-22 2020-01-01           영업/정상
# 3              3 2016-07-15 2020-01-01           영업/정상
# 4              4 2023-03-09 2020-01-01           영업/정상
# ...          ...        ...        ...             ...
# 8554        8554 2008-01-09 2012-03-16  취소/말소/만료/정지/중지
# 8555        8555 2007-10-30 2011-03-18  취소/말소/만료/정지/중지
# 8556        8556 2007-12-14 2021-02-03  취소/말소/만료/정지/중지
# 8557        8557 2000-12-30 2020-01-01  취소/말소/만료/정지/중지
# 8558        8558 2000-03-16 2020-01-01  취소/말소/만료/정지/중지
#
#                                                   도로명주소  \
# 0                   서울특별시 영등포구 영등포로 218-1, 제3호 (영등포동3가)
# 1                     서울특별시 성북구 오패산로 16, 구원빌딩 1층 (하월곡동)
# 2                          서울특별시 성북구 솔샘로6길 46, 2층 (정릉동)
# 3                           서울특별시 영등포구 경인로 857 (영등포동3가)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
del pcdata['Unnamed: 0']

# %%
pcdata[pcdata['구별']=='삼양동사거리입구']
# Out:
#           인허가일자       폐업일자  영업상태명                                     도로명주소  \
# 8461 1999-06-26 2020-01-01  영업/정상  삼양동사거리입구, 솔샘로, 송천동, 강북구, 서울, 01179, 대한민국
#
#         사업장명        좌표정보(X)        좌표정보(Y)         위도          경도        구별  \
# 8461  월드넷PC방  202520.944619  457486.861169  37.616971  127.028554  삼양동사거리입구
#
#         시군구
# 8461  서울특별시

# %%
pcdata.loc[8461,'구별'] = '강북구'

# %%
pcdata.loc[8461]
# Out:
# 인허가일자                           1999-06-26 00:00:00
# 폐업일자                            2020-01-01 00:00:00
# 영업상태명                                         영업/정상
# 도로명주소      삼양동사거리입구, 솔샘로, 송천동, 강북구, 서울, 01179, 대한민국
# 사업장명                                         월드넷PC방
# 좌표정보(X)                               202520.944619
# 좌표정보(Y)                               457486.861169
# 위도                                        37.616971
# 경도                                       127.028554
# 구별                                              강북구
# 시군구                                           서울특별시
# Name: 8461, dtype: object

# %%
pcdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8559 entries, 0 to 8558
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   인허가일자    8559 non-null   datetime64[ns]
#  1   폐업일자     8559 non-null   datetime64[ns]
#  2   영업상태명    8559 non-null   object
#  3   도로명주소    8559 non-null   object
#  4   사업장명     8559 non-null   object
#  5   좌표정보(X)  8547 non-null   float64
#  6   좌표정보(Y)  8547 non-null   float64
#  7   위도       8547 non-null   float64
#  8   경도       8547 non-null   float64
#  9   구별       8559 non-null   object
#  10  시군구      8559 non-null   object
# dtypes: datetime64[ns](2), float64(4), object(5)
# memory usage: 735.7+ KB

# %%
pcdata =pcdata[['시군구', '구별', '인허가일자','폐업일자', '도로명주소', '사업장명','위도','경도']]
pcdata
# Out:
#         시군구    구별      인허가일자       폐업일자  \
# 0     서울특별시  영등포구 2020-11-06 2020-01-01
# 1     서울특별시   성북구 2019-05-20 2020-01-01
# 2     서울특별시   성북구 2017-05-22 2020-01-01
# 3     서울특별시  영등포구 2016-07-15 2020-01-01
# 4     서울특별시   송파구 2023-03-09 2020-01-01
# ...     ...   ...        ...        ...
# 8554  서울특별시   관악구 2008-01-09 2012-03-16
# 8555  서울특별시   관악구 2007-10-30 2011-03-18
# 8556  서울특별시   서초구 2007-12-14 2021-02-03
# 8557  서울특별시   강남구 2000-12-30 2020-01-01
# 8558  서울특별시   강남구 2000-03-16 2020-01-01
#
#                                                   도로명주소  \
# 0                   서울특별시 영등포구 영등포로 218-1, 제3호 (영등포동3가)
# 1                     서울특별시 성북구 오패산로 16, 구원빌딩 1층 (하월곡동)
# 2                          서울특별시 성북구 솔샘로6길 46, 2층 (정릉동)
# 3                           서울특별시 영등포구 경인로 857 (영등포동3가)
# 4                     서울특별시 송파구 중대로9길 46, 2층 201호 (가락동)
# ...                                                 ...
# 8554                     난곡로, 난곡동, 관악구, 서울, 08858, 대한민국
# ...

# %%
pcdata = pcdata.sort_values('폐업일자')

# %%
pcdata
# Out:
#         시군구    구별      인허가일자       폐업일자                             도로명주소  \
# 4080  서울특별시   은평구 1999-11-15 2007-05-18      서울특별시 은평구 증산로15길 25 (신사동,2층)
# 3187  서울특별시   강북구 2001-11-30 2008-02-22        서울특별시 강북구 한천로 940  (번동,2층)
# 4346  서울특별시  서대문구 1999-12-27 2008-02-26          서울특별시 서대문구 연세로 36  (창천동)
# 6890  서울특별시   동작구 1999-09-29 2008-08-01        서울특별시 동작구 노량진로 104  (노량진동)
# 1999  서울특별시  동대문구 2001-08-17 2008-08-01   서울특별시 동대문구 전농로4나길 35  (답십리동,2층)
# ...     ...   ...        ...        ...                               ...
# 8278  서울특별시   강동구 2014-08-01 2023-05-18    서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시   성동구 2007-11-16 2023-05-22  서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시   은평구 2007-10-24 2023-06-07      서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시   은평구 2007-11-13 2023-06-07       서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시   은평구 2008-02-27 2023-06-07       서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                 사업장명         위도          경도
# ...

# %%
pc= pcdata[pcdata['폐업일자'] >= '2017-12-31']
pc
# Out:
#         시군구   구별      인허가일자       폐업일자                             도로명주소  \
# 5092  서울특별시  양천구 2008-05-19 2018-01-02     서울특별시 양천구 곰달래로14길 10 (신월동,2층)
# 779   서울특별시  용산구 2015-07-02 2018-02-06   서울특별시 용산구 새창로 131-6, 2층 (원효로2가)
# 775   서울특별시  용산구 2009-08-07 2018-02-06  서울특별시 용산구 새창로14길 17 (용문동, 이원리츠빌)
# 3747  서울특별시  은평구 2013-04-24 2018-03-27       서울특별시 은평구 통일로 915, 2층 (갈현동)
# 3785  서울특별시  은평구 2008-10-03 2018-03-27       서울특별시 은평구 통일로 709 (대조동,지1층)
# ...     ...  ...        ...        ...                               ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18    서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시  성동구 2007-11-16 2023-05-22  서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시  은평구 2007-10-24 2023-06-07      서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시  은평구 2007-11-13 2023-06-07       서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시  은평구 2008-02-27 2023-06-07       서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                사업장명         위도          경도
# 5092        레볼루션 PC  37.526475  126.837066
# ...

# %%
pcs = pc.sort_values('인허가일자')
pcs
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 1398  서울특별시  광진구 1992-10-10 2020-07-23
# 3829  서울특별시  은평구 1996-07-08 2022-02-22
# 4069  서울특별시  은평구 1996-07-08 2022-02-22
# 3916  서울특별시  은평구 1996-07-10 2022-02-22
# ...     ...  ...        ...        ...
# 191   서울특별시  도봉구 2023-06-29 2020-01-01
# 186   서울특별시  관악구 2023-06-29 2020-01-01
# 187   서울특별시  관악구 2023-06-29 2020-01-01
# 194   서울특별시  광진구 2023-06-30 2020-01-01
# 192   서울특별시  강북구 2023-07-06 2020-01-01
#
#                                         도로명주소           사업장명         위도  \
# 621                    서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 1398           서울특별시 광진구 능동로 216, 어린이대공원 (능동)             과학  37.546839
# 3829                  서울특별시 은평구 갈현로 297 (갈현동)           월드게임  37.620611
# 4069                  서울특별시 은평구 통일로 623 (녹번동)         테크노프라자  37.599701
# 3916             서울특별시 은평구 불광로 28 (대조동,2층10호)         게임기 천국  37.607788
# ...

# %%
pc17= pc[pc['인허가일자'] < '2018-01-01']
pc17
# Out:
#         시군구   구별      인허가일자       폐업일자                             도로명주소  \
# 5092  서울특별시  양천구 2008-05-19 2018-01-02     서울특별시 양천구 곰달래로14길 10 (신월동,2층)
# 779   서울특별시  용산구 2015-07-02 2018-02-06   서울특별시 용산구 새창로 131-6, 2층 (원효로2가)
# 775   서울특별시  용산구 2009-08-07 2018-02-06  서울특별시 용산구 새창로14길 17 (용문동, 이원리츠빌)
# 3747  서울특별시  은평구 2013-04-24 2018-03-27       서울특별시 은평구 통일로 915, 2층 (갈현동)
# 3785  서울특별시  은평구 2008-10-03 2018-03-27       서울특별시 은평구 통일로 709 (대조동,지1층)
# ...     ...  ...        ...        ...                               ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18    서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시  성동구 2007-11-16 2023-05-22  서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시  은평구 2007-10-24 2023-06-07      서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시  은평구 2007-11-13 2023-06-07       서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시  은평구 2008-02-27 2023-06-07       서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                사업장명         위도          경도
# 5092        레볼루션 PC  37.526475  126.837066
# ...

# %%
pc17_ = pc17.groupby('구별').count()

# %%
pc17_
# Out:
#       시군구  인허가일자  폐업일자  도로명주소  사업장명   위도   경도
# 구별
# 강남구   421    421   421    421   421  421  421
# 강동구   197    197   197    197   197  197  197
# 강북구   357    357   357    357   357  357  357
# 강서구   458    458   458    458   458  458  458
# 관악구   162    162   162    162   162  162  162
# 광진구   128    128   128    128   128  128  128
# 구로구   178    178   178    178   178  178  178
# 금천구   139    139   139    139   139  139  139
# 노원구    77     77    77     77    77   77   77
# 도봉구   298    298   298    298   298  298  298
# 동대문구   94     94    94     94    94   94   94
# 동작구   157    157   157    157   157  157  157
# 마포구   313    313   313    313   313  313  313
# 서대문구  101    101   101    101   101  101  101
# 서초구   162    162   162    162   162  162  162
# 성동구   305    305   305    305   305  305  305
# 성북구    79     79    79     79    79   79   79
# 송파구   221    221   221    221   221  221  221
# 양천구   371    371   371    371   371  371  371
# ...

# %%
pc17_ = pc17_.reset_index()
pc17_df = pc17_[['구별','시군구']]

# %%
pc17_df
# Out:
#       구별  시군구
# 0    강남구  421
# 1    강동구  197
# 2    강북구  357
# 3    강서구  458
# 4    관악구  162
# 5    광진구  128
# 6    구로구  178
# 7    금천구  139
# 8    노원구   77
# 9    도봉구  298
# 10  동대문구   94
# 11   동작구  157
# 12   마포구  313
# 13  서대문구  101
# 14   서초구  162
# 15   성동구  305
# 16   성북구   79
# 17   송파구  221
# 18   양천구  371
# 19  영등포구  156
# 20   용산구   34
# 21   은평구  410
# 22   종로구   51
# 23    중구  144
# 24   중랑구  422

# %%
pcdata = pcdata.sort_values('폐업일자')
pcdata
# Out:
#         시군구    구별      인허가일자       폐업일자                             도로명주소  \
# 4080  서울특별시   은평구 1999-11-15 2007-05-18      서울특별시 은평구 증산로15길 25 (신사동,2층)
# 3187  서울특별시   강북구 2001-11-30 2008-02-22        서울특별시 강북구 한천로 940  (번동,2층)
# 4346  서울특별시  서대문구 1999-12-27 2008-02-26          서울특별시 서대문구 연세로 36  (창천동)
# 6907  서울특별시   동작구 1999-11-03 2008-08-01        서울특별시 동작구 신대방길 113  (신대방동)
# 6906  서울특별시   동작구 1999-09-29 2008-08-01          서울특별시 동작구 사당로 244  (사당동)
# ...     ...   ...        ...        ...                               ...
# 8278  서울특별시   강동구 2014-08-01 2023-05-18    서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시   성동구 2007-11-16 2023-05-22  서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시   은평구 2007-10-24 2023-06-07      서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시   은평구 2007-11-13 2023-06-07       서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시   은평구 2008-02-27 2023-06-07       서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                사업장명         위도          경도
# ...

# %%
pcdata = pcdata.sort_values('인허가일자')
pcdata
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 1525  서울특별시  광진구 1985-03-02 2014-03-20
# 1526  서울특별시  광진구 1985-03-23 2014-03-19
# 1529  서울특별시  광진구 1985-03-29 2014-03-20
# 1530  서울특별시  광진구 1985-04-02 2014-03-20
# 1415  서울특별시  광진구 1985-04-04 2014-03-21
# ...     ...  ...        ...        ...
# 191   서울특별시  도봉구 2023-06-29 2020-01-01
# 190   서울특별시  광진구 2023-06-29 2020-01-01
# 186   서울특별시  관악구 2023-06-29 2020-01-01
# 194   서울특별시  광진구 2023-06-30 2020-01-01
# 192   서울특별시  강북구 2023-07-06 2020-01-01
#
#                                         도로명주소                   사업장명  \
# 1525                 서울특별시 광진구 아차산로 361 (자양동)     신라 무단폐업 2000-04-14
# 1526               서울특별시 광진구 천호대로112길 10 (능동)     최신 무단폐업 2001-03-13
# 1529                  서울특별시 광진구 능동로 373 (중곡동)     최신 무단폐업 2000-09-30
# 1530                  서울특별시 광진구 면목로 172 (중곡동)     성동 무단폐업 2002-07-11
# 1415                  서울특별시 광진구 용마산로 38 (중곡동)  중곡오락실 무단폐업 2003-05-27
# ...                                       ...                    ...
# ...

# %%
pc= pcdata[pcdata['폐업일자'] > '2018-12-31']
pc
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 1398  서울특별시  광진구 1992-10-10 2020-07-23
# 4069  서울특별시  은평구 1996-07-08 2022-02-22
# 3829  서울특별시  은평구 1996-07-08 2022-02-22
# 3916  서울특별시  은평구 1996-07-10 2022-02-22
# ...     ...  ...        ...        ...
# 191   서울특별시  도봉구 2023-06-29 2020-01-01
# 190   서울특별시  광진구 2023-06-29 2020-01-01
# 186   서울특별시  관악구 2023-06-29 2020-01-01
# 194   서울특별시  광진구 2023-06-30 2020-01-01
# 192   서울특별시  강북구 2023-07-06 2020-01-01
#
#                                         도로명주소           사업장명         위도  \
# 621                    서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 1398           서울특별시 광진구 능동로 216, 어린이대공원 (능동)             과학  37.546839
# 4069                  서울특별시 은평구 통일로 623 (녹번동)         테크노프라자  37.599701
# 3829                  서울특별시 은평구 갈현로 297 (갈현동)           월드게임  37.620611
# 3916             서울특별시 은평구 불광로 28 (대조동,2층10호)         게임기 천국  37.607788
# ...

# %%
pc18= pc[pc['인허가일자'] < '2019-01-01']
pc18
# Out:
#         시군구    구별      인허가일자       폐업일자  \
# 621   서울특별시    중구 1987-07-01 2020-01-01
# 1398  서울특별시   광진구 1992-10-10 2020-07-23
# 4069  서울특별시   은평구 1996-07-08 2022-02-22
# 3829  서울특별시   은평구 1996-07-08 2022-02-22
# 3916  서울특별시   은평구 1996-07-10 2022-02-22
# ...     ...   ...        ...        ...
# 6992  서울특별시   관악구 2018-12-24 2020-01-01
# 4143  서울특별시  서대문구 2018-12-27 2020-01-01
# 409   서울특별시   도봉구 2018-12-28 2020-01-01
# 339   서울특별시   도봉구 2018-12-28 2020-01-01
# 4178  서울특별시  서대문구 2018-12-31 2020-01-01
#
#                                           도로명주소       사업장명         위도  \
# 621                      서울특별시 중구 퇴계로 254 (묵정동)      충무오락실  37.559596
# 1398             서울특별시 광진구 능동로 216, 어린이대공원 (능동)         과학  37.546839
# 4069                    서울특별시 은평구 통일로 623 (녹번동)     테크노프라자  37.599701
# 3829                    서울특별시 은평구 갈현로 297 (갈현동)       월드게임  37.620611
# 3916               서울특별시 은평구 불광로 28 (대조동,2층10호)     게임기 천국  37.607788
# ...

# %%
pc18_ = pc18.groupby('구별').count()
pc18_ = pc18_.reset_index()
pc18_df = pc18_[['구별','시군구']]
pc18_df
# Out:
#       구별  시군구
# 0    강남구  436
# 1    강동구  219
# 2    강북구  370
# 3    강서구  473
# 4    관악구  168
# 5    광진구  145
# 6    구로구  184
# 7    금천구  147
# 8    노원구   90
# 9    도봉구  313
# 10  동대문구  108
# 11   동작구  165
# 12   마포구   90
# 13  서대문구  114
# 14   서초구  169
# 15   성동구  310
# 16   성북구   87
# 17   송파구  237
# 18   양천구  377
# 19  영등포구  157
# 20   용산구   29
# 21   은평구  403
# 22   종로구   57
# 23    중구  151
# 24   중랑구  445

# %%
pcdata = pcdata.sort_values('폐업일자')
pcdata
# Out:
#         시군구    구별      인허가일자       폐업일자                             도로명주소  \
# 4080  서울특별시   은평구 1999-11-15 2007-05-18      서울특별시 은평구 증산로15길 25 (신사동,2층)
# 3187  서울특별시   강북구 2001-11-30 2008-02-22        서울특별시 강북구 한천로 940  (번동,2층)
# 4346  서울특별시  서대문구 1999-12-27 2008-02-26          서울특별시 서대문구 연세로 36  (창천동)
# 6797  서울특별시   동작구 2001-05-19 2008-08-01       서울특별시 동작구 동작대로29길 57  (사당동)
# 6796  서울특별시   동작구 2001-05-11 2008-08-01     서울특별시 동작구 만양로18길 19-3  (노량진동)
# ...     ...   ...        ...        ...                               ...
# 8278  서울특별시   강동구 2014-08-01 2023-05-18    서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시   성동구 2007-11-16 2023-05-22  서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시   은평구 2007-10-24 2023-06-07      서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시   은평구 2007-11-13 2023-06-07       서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시   은평구 2008-02-27 2023-06-07       서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                사업장명         위도          경도
# ...

# %%
pc= pcdata[pcdata['폐업일자'] > '2019-12-31']
pc
# Out:
#         시군구   구별      인허가일자       폐업일자                               도로명주소  \
# 5894  서울특별시  구로구 2010-12-17 2020-01-01    서울특별시 구로구 경인로35길 118-4  (고척동,1층)
# 5217  서울특별시  강서구 2017-03-28 2020-01-01      서울특별시 강서구 강서로17길 117, 1층 (화곡동)
# 5337  서울특별시  강서구 1999-10-09 2020-01-01           서울특별시 강서구 까치산로 106  (화곡동)
# 5338  서울특별시  강서구 1999-10-11 2020-01-01     서울특별시 강서구 양천로 126  (방화동,영상빌딩6층)
# 5218  서울특별시  강서구 2020-07-16 2020-01-01  서울특별시 강서구 강서로 205, 세종빌딩 지하2층 (화곡동)
# ...     ...  ...        ...        ...                                 ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18      서울특별시 강동구 양재대로 1481, 지하1층 (길동)
# 860   서울특별시  성동구 2007-11-16 2023-05-22    서울특별시 성동구 장터길 38-1, 지하2층 (금호동4가)
# 171   서울특별시  은평구 2007-10-24 2023-06-07        서울특별시 은평구 증산로7길 16 (증산동,지1층)
# 3697  서울특별시  은평구 2007-11-13 2023-06-07         서울특별시 은평구 응암로13길 6 (응암동,3층)
# 2361  서울특별시  은평구 2008-02-27 2023-06-07         서울특별시 은평구 통일로 822, 지층 (불광동)
#
#                사업장명         위도          경도
# ...

# %%
pc_ = pc.sort_values('인허가일자')
pc_
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 1398  서울특별시  광진구 1992-10-10 2020-07-23
# 4069  서울특별시  은평구 1996-07-08 2022-02-22
# 3829  서울특별시  은평구 1996-07-08 2022-02-22
# 3916  서울특별시  은평구 1996-07-10 2022-02-22
# ...     ...  ...        ...        ...
# 191   서울특별시  도봉구 2023-06-29 2020-01-01
# 190   서울특별시  광진구 2023-06-29 2020-01-01
# 187   서울특별시  관악구 2023-06-29 2020-01-01
# 194   서울특별시  광진구 2023-06-30 2020-01-01
# 192   서울특별시  강북구 2023-07-06 2020-01-01
#
#                                         도로명주소    사업장명         위도          경도
# 621                    서울특별시 중구 퇴계로 254 (묵정동)   충무오락실  37.559596  126.999145
# 1398           서울특별시 광진구 능동로 216, 어린이대공원 (능동)      과학  37.546839  127.080784
# 4069                  서울특별시 은평구 통일로 623 (녹번동)  테크노프라자  37.599701  126.934004
# 3829                  서울특별시 은평구 갈현로 297 (갈현동)    월드게임  37.620611  126.916032
# 3916             서울특별시 은평구 불광로 28 (대조동,2층10호)  게임기 천국  37.607788  126.928513
# ...

# %%
pc19= pc_[pc_['인허가일자'] < '2020-01-01']
pc19
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 1398  서울특별시  광진구 1992-10-10 2020-07-23
# 4069  서울특별시  은평구 1996-07-08 2022-02-22
# 3829  서울특별시  은평구 1996-07-08 2022-02-22
# 3916  서울특별시  은평구 1996-07-10 2022-02-22
# ...     ...  ...        ...        ...
# 3552  서울특별시  노원구 2019-12-24 2020-01-01
# 8142  서울특별시  강동구 2019-12-26 2020-01-01
# 6527  서울특별시  동작구 2019-12-26 2020-01-01
# 391   서울특별시  양천구 2019-12-26 2020-01-01
# 6525  서울특별시  동작구 2019-12-31 2020-01-01
#
#                                                   도로명주소             사업장명  \
# 621                              서울특별시 중구 퇴계로 254 (묵정동)            충무오락실
# 1398                     서울특별시 광진구 능동로 216, 어린이대공원 (능동)               과학
# 4069                            서울특별시 은평구 통일로 623 (녹번동)           테크노프라자
# 3829                            서울특별시 은평구 갈현로 297 (갈현동)             월드게임
# 3916                       서울특별시 은평구 불광로 28 (대조동,2층10호)           게임기 천국
# ...

# %%
pc19_ = pc19.groupby('구별').count()
pc19_ = pc19_.reset_index()
pc19_df = pc19_[['구별','시군구']]
pc19_df
# Out:
#       구별  시군구
# 0    강남구  457
# 1    강동구  229
# 2    강북구  379
# 3    강서구  480
# 4    관악구  178
# 5    광진구  151
# 6    구로구  194
# 7    금천구  156
# 8    노원구  104
# 9    도봉구  324
# 10  동대문구  120
# 11   동작구  171
# 12   마포구   44
# 13  서대문구   65
# 14   서초구  174
# 15   성동구  193
# 16   성북구   80
# 17   송파구  244
# 18   양천구  386
# 19  영등포구  165
# 20   용산구   30
# 21   은평구  407
# 22   종로구   62
# 23    중구  153
# 24   중랑구  460

# %%
pcdf = pd.merge(pc17_df,pc18_df,on='구별')
pcdf
# Out:
#       구별  시군구_x  시군구_y
# 0    강남구    421    436
# 1    강동구    197    219
# 2    강북구    357    370
# 3    강서구    458    473
# 4    관악구    162    168
# 5    광진구    128    145
# 6    구로구    178    184
# 7    금천구    139    147
# 8    노원구     77     90
# 9    도봉구    298    313
# 10  동대문구     94    108
# 11   동작구    157    165
# 12   마포구    313     90
# 13  서대문구    101    114
# 14   서초구    162    169
# 15   성동구    305    310
# 16   성북구     79     87
# 17   송파구    221    237
# 18   양천구    371    377
# 19  영등포구    156    157
# 20   용산구     34     29
# 21   은평구    410    403
# 22   종로구     51     57
# 23    중구    144    151
# 24   중랑구    422    445

# %%
pcdf = pd.merge(pcdf,pc19_df,on='구별')
pcdf
# Out:
#       구별  시군구_x  시군구_y  시군구
# 0    강남구    421    436  457
# 1    강동구    197    219  229
# 2    강북구    357    370  379
# 3    강서구    458    473  480
# 4    관악구    162    168  178
# 5    광진구    128    145  151
# 6    구로구    178    184  194
# 7    금천구    139    147  156
# 8    노원구     77     90  104
# 9    도봉구    298    313  324
# 10  동대문구     94    108  120
# 11   동작구    157    165  171
# 12   마포구    313     90   44
# 13  서대문구    101    114   65
# 14   서초구    162    169  174
# 15   성동구    305    310  193
# 16   성북구     79     87   80
# 17   송파구    221    237  244
# 18   양천구    371    377  386
# 19  영등포구    156    157  165
# 20   용산구     34     29   30
# 21   은평구    410    403  407
# 22   종로구     51     57   62
# 23    중구    144    151  153
# 24   중랑구    422    445  460

# %%
pcdf.columns = [['구별','2017년','2018년','2019년']]
pcdf
# Out:
#       구별 2017년 2018년 2019년
# 0    강남구   421   436   457
# 1    강동구   197   219   229
# 2    강북구   357   370   379
# 3    강서구   458   473   480
# 4    관악구   162   168   178
# 5    광진구   128   145   151
# 6    구로구   178   184   194
# 7    금천구   139   147   156
# 8    노원구    77    90   104
# 9    도봉구   298   313   324
# 10  동대문구    94   108   120
# 11   동작구   157   165   171
# 12   마포구   313    90    44
# 13  서대문구   101   114    65
# 14   서초구   162   169   174
# 15   성동구   305   310   193
# 16   성북구    79    87    80
# 17   송파구   221   237   244
# 18   양천구   371   377   386
# 19  영등포구   156   157   165
# 20   용산구    34    29    30
# 21   은평구   410   403   407
# 22   종로구    51    57    62
# 23    중구   144   151   153
# 24   중랑구   422   445   460

# %%
pcdata = pcdata.sort_values('폐업일자')
pcdata
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 8460  서울특별시  강북구 2000-12-26 2020-01-01
# 3357  서울특별시  도봉구 2000-12-27 2020-01-01
# 5046  서울특별시  양천구 2000-12-28 2020-01-01
# 5044  서울특별시  양천구 2000-12-16 2020-01-01
# ...     ...  ...        ...        ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18
# 860   서울특별시  성동구 2007-11-16 2023-05-22
# 171   서울특별시  은평구 2007-10-24 2023-06-07
# 2361  서울특별시  은평구 2008-02-27 2023-06-07
# 3697  서울특별시  은평구 2007-11-13 2023-06-07
#
#                                        도로명주소           사업장명         위도  \
# 621                   서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 8460  103, 월계로37길, 번3동, 강북구, 서울, 01224, 대한민국           게임랜드  37.624724
# 3357             서울특별시 도봉구 도당로 129  (방학동,2층)            마우스  37.664736
# 5046                서울특별시 양천구 신월로 301  (신정동)        선영아 사랑해  37.518819
# 5044              서울특별시 양천구 지양로 36  (신월동,3층)          PC프랜드  37.516863
# ...

# %%
pc = pcdata[(pcdata['폐업일자'] > '2021-12-31') | (pcdata['폐업일자'] == '2020-01-01')]

# %%
pc
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 8460  서울특별시  강북구 2000-12-26 2020-01-01
# 3357  서울특별시  도봉구 2000-12-27 2020-01-01
# 5046  서울특별시  양천구 2000-12-28 2020-01-01
# 5044  서울특별시  양천구 2000-12-16 2020-01-01
# ...     ...  ...        ...        ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18
# 860   서울특별시  성동구 2007-11-16 2023-05-22
# 171   서울특별시  은평구 2007-10-24 2023-06-07
# 2361  서울특별시  은평구 2008-02-27 2023-06-07
# 3697  서울특별시  은평구 2007-11-13 2023-06-07
#
#                                        도로명주소           사업장명         위도  \
# 621                   서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 8460  103, 월계로37길, 번3동, 강북구, 서울, 01224, 대한민국           게임랜드  37.624724
# 3357             서울특별시 도봉구 도당로 129  (방학동,2층)            마우스  37.664736
# 5046                서울특별시 양천구 신월로 301  (신정동)        선영아 사랑해  37.518819
# 5044              서울특별시 양천구 지양로 36  (신월동,3층)          PC프랜드  37.516863
# ...

# %%
pcdata = pc.sort_values('인허가일자')
pcdata
# Out:
#         시군구   구별      인허가일자       폐업일자                               도로명주소  \
# 621   서울특별시   중구 1987-07-01 2020-01-01              서울특별시 중구 퇴계로 254 (묵정동)
# 3829  서울특별시  은평구 1996-07-08 2022-02-22             서울특별시 은평구 갈현로 297 (갈현동)
# 4069  서울특별시  은평구 1996-07-08 2022-02-22             서울특별시 은평구 통일로 623 (녹번동)
# 3916  서울특별시  은평구 1996-07-10 2022-02-22        서울특별시 은평구 불광로 28 (대조동,2층10호)
# 3917  서울특별시  은평구 1996-07-26 2022-02-22              서울특별시 은평구 불광로 28 (대조동)
# ...     ...  ...        ...        ...                                 ...
# 187   서울특별시  관악구 2023-06-29 2020-01-01       서울특별시 관악구 신림로66길 20, 2층 (신림동)
# 186   서울특별시  관악구 2023-06-29 2020-01-01       서울특별시 관악구 관천로 38 (신림동, 푸리마타운)
# 190   서울특별시  광진구 2023-06-29 2020-01-01  서울특별시 광진구 아차산로 353, 금강태극빌 2층 (자양동)
# 194   서울특별시  광진구 2023-06-30 2020-01-01       서울특별시 광진구 면목로 195, 진웅빌딩 (중곡동)
# 192   서울특별시  강북구 2023-07-06 2020-01-01          서울특별시 강북구 인수봉로85길 24 (수유동)
#
#                사업장명         위도          경도
# ...

# %%
pc21= pc[pc['인허가일자'] < '2022-01-01']
pc21
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 8460  서울특별시  강북구 2000-12-26 2020-01-01
# 3357  서울특별시  도봉구 2000-12-27 2020-01-01
# 5046  서울특별시  양천구 2000-12-28 2020-01-01
# 5044  서울특별시  양천구 2000-12-16 2020-01-01
# ...     ...  ...        ...        ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18
# 860   서울특별시  성동구 2007-11-16 2023-05-22
# 171   서울특별시  은평구 2007-10-24 2023-06-07
# 2361  서울특별시  은평구 2008-02-27 2023-06-07
# 3697  서울특별시  은평구 2007-11-13 2023-06-07
#
#                                        도로명주소           사업장명         위도  \
# 621                   서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 8460  103, 월계로37길, 번3동, 강북구, 서울, 01224, 대한민국           게임랜드  37.624724
# 3357             서울특별시 도봉구 도당로 129  (방학동,2층)            마우스  37.664736
# 5046                서울특별시 양천구 신월로 301  (신정동)        선영아 사랑해  37.518819
# 5044              서울특별시 양천구 지양로 36  (신월동,3층)          PC프랜드  37.516863
# ...

# %%
pc21_ = pc21.groupby('구별').count()
pc21_ = pc21_.reset_index()
pc21_df = pc21_[['구별','시군구']]
pc21_df.head()
# Out:
#     구별  시군구
# 0  강남구  432
# 1  강동구  239
# 2  강북구  367
# 3  강서구  418
# 4  관악구  173

# %%
pcdf.head()
# Out:
#     구별 2017년 2018년 2019년
# 0  강남구   421   436   457
# 1  강동구   197   219   229
# 2  강북구   357   370   379
# 3  강서구   458   473   480
# 4  관악구   162   168   178

# %%
pcdf.to_excel('/content/sample_data/3개년PC방.xlsx',encoding = 'utf-8')

# %%
pc21_df.columns = [['구별','2021년']]
pc21_df
# Out:
#       구별 2021년
# 0    강남구   432
# 1    강동구   239
# 2    강북구   367
# 3    강서구   418
# 4    관악구   173
# 5    광진구   107
# 6    구로구   203
# 7    금천구   127
# 8    노원구   111
# 9    도봉구   335
# 10  동대문구   133
# 11   동작구   174
# 12   마포구    48
# 13  서대문구    54
# 14   서초구    91
# 15   성동구   163
# 16   성북구    83
# 17   송파구   250
# 18   양천구   326
# 19  영등포구   130
# 20   용산구    24
# 21   은평구   410
# 22   종로구    47
# 23    중구   159
# 24   중랑구   446

# %%
pc21.to_excel('/content/sample_data/2021년PC방.xlsx',encoding = 'utf-8')

# %%
pc21
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 8460  서울특별시  강북구 2000-12-26 2020-01-01
# 3357  서울특별시  도봉구 2000-12-27 2020-01-01
# 5046  서울특별시  양천구 2000-12-28 2020-01-01
# 5044  서울특별시  양천구 2000-12-16 2020-01-01
# ...     ...  ...        ...        ...
# 8278  서울특별시  강동구 2014-08-01 2023-05-18
# 860   서울특별시  성동구 2007-11-16 2023-05-22
# 171   서울특별시  은평구 2007-10-24 2023-06-07
# 2361  서울특별시  은평구 2008-02-27 2023-06-07
# 3697  서울특별시  은평구 2007-11-13 2023-06-07
#
#                                        도로명주소           사업장명         위도  \
# 621                   서울특별시 중구 퇴계로 254 (묵정동)          충무오락실  37.559596
# 8460  103, 월계로37길, 번3동, 강북구, 서울, 01224, 대한민국           게임랜드  37.624724
# 3357             서울특별시 도봉구 도당로 129  (방학동,2층)            마우스  37.664736
# 5046                서울특별시 양천구 신월로 301  (신정동)        선영아 사랑해  37.518819
# 5044              서울특별시 양천구 지양로 36  (신월동,3층)          PC프랜드  37.516863
# ...

# %%
pc17.to_excel('/content/sample_data/2017년PC방.xlsx',encoding = 'utf-8')

# %%
pc18.to_excel('/content/sample_data/2018년PC방.xlsx',encoding = 'utf-8')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
pc19.to_excel('/content/sample_data/2019년PC방.xlsx',encoding = 'utf-8')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
pc19
# Out:
#         시군구   구별      인허가일자       폐업일자  \
# 621   서울특별시   중구 1987-07-01 2020-01-01
# 1398  서울특별시  광진구 1992-10-10 2020-07-23
# 4069  서울특별시  은평구 1996-07-08 2022-02-22
# 3829  서울특별시  은평구 1996-07-08 2022-02-22
# 3916  서울특별시  은평구 1996-07-10 2022-02-22
# ...     ...  ...        ...        ...
# 3552  서울특별시  노원구 2019-12-24 2020-01-01
# 8142  서울특별시  강동구 2019-12-26 2020-01-01
# 6527  서울특별시  동작구 2019-12-26 2020-01-01
# 391   서울특별시  양천구 2019-12-26 2020-01-01
# 6525  서울특별시  동작구 2019-12-31 2020-01-01
#
#                                                   도로명주소             사업장명  \
# 621                              서울특별시 중구 퇴계로 254 (묵정동)            충무오락실
# 1398                     서울특별시 광진구 능동로 216, 어린이대공원 (능동)               과학
# 4069                            서울특별시 은평구 통일로 623 (녹번동)           테크노프라자
# 3829                            서울특별시 은평구 갈현로 297 (갈현동)             월드게임
# 3916                       서울특별시 은평구 불광로 28 (대조동,2층10호)           게임기 천국
# ...
