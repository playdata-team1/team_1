# %%
import pandas as pd
pc = pd.read_csv('../../Downloads/서울시 인터넷컴퓨터게임시설제공업 인허가 정보.csv',encoding='cp949')
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_2816\726605754.py:2: DtypeWarning: Columns (2,3,6,8,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   pc = pd.read_csv('../../Downloads/서울시 인터넷컴퓨터게임시설제공업 인허가 정보.csv',encoding='cp949')
