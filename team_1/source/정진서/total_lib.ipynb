# %%
import pandas as pd
import numpy as np
import glob
import matplotlib as mat
import matplotlib.pyplot as plt
import seaborn as sns
import xlrd
import platform
import json
import googlemaps
import folium
from matplotlib import font_manager , rc
f_path = "/Library/Fonts/Arial Unicode.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
gmaps_key = "AIzaSyA4lognWEmzHerB9fu8UZYyEjyEMgRJAws"
gmaps = googlemaps.Client(key=gmaps_key)

# %% [markdown]
# # 서울시 203개 도서관

# %%
lib = pd.read_excel('../data/공공도서관 통계데이터_2017~2019.xlsx')
lib.head()
# Out:
#              도서관명     도서관부호  지역  시군구 설립주체  개관년도                         주소  \
# 0   4.19 혁명기념 도서관  111001.0  서울  종로구   사립  2000     서울특별시 종로구 새문안로 17 (평동)
# 1          가락몰도서관  111456.0  서울  송파구   사립  2016   서울특별시 송파구 양재대로 932 (가락동)
# 2           가온도서관  111108.0  서울   중구  지자체  2008            서울특별시 중구 동호로14길
# 3           갈산도서관  128040.0  서울  양천구  지자체  2014          서울특별시 양천구 목동남로 4길
# 4  강남구립 역삼푸른솔 도서관  111127.0  서울  강남구  지자체  2009  서울특별시 강남구 테헤란로8길 36 (역삼동)
#
#                상세주소          전화번호            팩스  \
# 0       4.19혁명기념도서관   02-730-4190   02-737-9557
# 1        가락몰 업무동 4층  02-3435-0950  02-3435-0959
# 2        18 (가온도서관)  02-2230-2921  02-2285-4607
# 3        48-6 갈산도서관  02-2645-5919           NaN
# 4  4층 강남구립 역삼푸른솔도서관  02-2051-1178  02-2051-1103
#
#                                             홈페이지
# 0               http://library.419revolution.org
# 1                 http://www.splib.or.kr/spalib/
# 2                   http://www.e-junggulib.or.kr
# 3         https://lib.yangcheon.or.kr/libgalsan/
# 4  https://library.gangnam.go.kr/ysplib/index.do

# %%
lib = lib[['도서관명', '지역', '시군구', '개관년도', '주소']]

# %% [markdown]
# # 주소 위도 경도로 변환

# %%
location_list = lib['주소'].to_list()

# %%
location_lat = []
location_lng = []
for name in location_list:
    tmp = gmaps.geocode(name, language='ko')
    
    if tmp:
        tmp_loc = tmp[0].get("geometry")
        if tmp_loc:
            location_lat.append(tmp_loc['location']['lat'])
            location_lng.append(tmp_loc['location']['lng'])
        else:
            # 유효한 결과가 없는 경우 처리
            location_lat.append(None)
            location_lng.append(None)
    else:
        # 결과가 없는 경우 처리
        location_lat.append(None)
        location_lng.append(None)

# %%
lat = pd.Series(location_lat)
lon = pd.Series(location_lng)

# %%
lib['lat'] = lat
lib['lon'] = lon

# %%
lib
# Out:
#                도서관명  지역   시군구  개관년도                           주소        lat  \
# 0     4.19 혁명기념 도서관  서울   종로구  2000       서울특별시 종로구 새문안로 17 (평동)  37.567916
# 1            가락몰도서관  서울   송파구  2016     서울특별시 송파구 양재대로 932 (가락동)  37.493482
# 2             가온도서관  서울    중구  2008              서울특별시 중구 동호로14길  37.556653
# 3             갈산도서관  서울   양천구  2014            서울특별시 양천구 목동남로 4길  37.508501
# 4    강남구립 역삼푸른솔 도서관  서울   강남구  2009    서울특별시 강남구 테헤란로8길 36 (역삼동)  37.496491
# ..              ...  ..   ...   ...                          ...        ...
# 198        종암동새날도서관  서울   성북구  2011              서울 성북구 종암로 98-8  37.598997
# 199       중랑숲어린이도서관  서울   중랑구  2012  서울특별시 중랑구 망우로73길 46-1 (망우동)  37.602660
# 200        하계어린이도서관  서울   노원구  2021    서울특별시 노원구 공릉로62길 18 (하계동)  37.641990
# 201          해오름도서관  서울   성북구  2009                   서울 성북구 돈암동  37.597795
# 202        휘경어린이도서관  서울  동대문구  2014        서울특별시 동대문구 망우로18가길 38  37.588658
#
#             lon
# 0    126.966862
# 1    127.111504
# 2    127.010213
# 3    126.866634
# 4    127.031845
# ..          ...
# 198  127.035111
# 199  127.103881
# 200  127.074643
# 201  127.018283
# 202  127.060623
#
# [203 rows x 7 columns]

# %%
lib.isnull()
# Out:
#       도서관명     지역    시군구   개관년도     주소    lat    lon
# 0    False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...
# 198  False  False  False  False  False  False  False
# 199  False  False  False  False  False  False  False
# 200  False  False  False  False  False  False  False
# 201  False  False  False  False  False  False  False
# 202  False  False  False  False  False  False  False
#
# [203 rows x 7 columns]

# %% [markdown]
# # 널값인 위도 경도 찾아서 값 넣기

# %%
null = lib[lib['lon'].isnull()]
null
# Out:
#        도서관명  지역  시군구  개관년도                                  주소  lat  lon
# 49  달빛마루도서관  서울  성북구  2012  서울특별시 성북구 종암로 167 (하월곡동, 동일하이빌뉴시티)  NaN  NaN
# 51    대치도서관  서울  강남구  1999      서울특별시 강남구 삼성로 212 (대치동, 은마아파트)  NaN  NaN

# %%
# 37.605235 127.030993
# 37.496087 127.064071

# %%
lib.at[49, 'lat'] = '37.605235'
lib.at[49, 'lon'] = '127.030993'

lib.at[51, 'lat'] = '37.496087'
lib.at[51, 'lon'] = '127.064071'

# %%
lib.iloc[51]
# Out:
# 도서관명                             대치도서관
# 지역                                  서울
# 시군구                                강남구
# 개관년도                              1999
# 주소      서울특별시 강남구 삼성로 212 (대치동, 은마아파트)
# lat                          37.496087
# lon                         127.064071
# Name: 51, dtype: object

# %% [markdown]
# # 새코드

# %% [markdown]
# # 개관년도 별 데이터 추출

# %%
lib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   도서관명    203 non-null    object
#  1   지역      203 non-null    object
#  2   시군구     203 non-null    object
#  3   개관년도    203 non-null    int64
#  4   주소      203 non-null    object
#  5   lat     203 non-null    object
#  6   lon     203 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 11.2+ KB

# %%
lib['개관년도'].astype(float)
# Out:
# 0      2000.0
# 1      2016.0
# 2      2008.0
# 3      2014.0
# 4      2009.0
#         ...
# 198    2011.0
# 199    2012.0
# 200    2021.0
# 201    2009.0
# 202    2014.0
# Name: 개관년도, Length: 203, dtype: float64

# %%
lib_2017_raw = lib[lib['개관년도'] < 2018]
lib_2018_raw = lib[lib['개관년도'] < 2019]
lib_2019_raw = lib[lib['개관년도'] < 2020]

# %%
lib_2017_raw
# Out:
#                도서관명  지역   시군구  개관년도                                 주소  \
# 0     4.19 혁명기념 도서관  서울   종로구  2000             서울특별시 종로구 새문안로 17 (평동)
# 1            가락몰도서관  서울   송파구  2016           서울특별시 송파구 양재대로 932 (가락동)
# 2             가온도서관  서울    중구  2008                    서울특별시 중구 동호로14길
# 3             갈산도서관  서울   양천구  2014                  서울특별시 양천구 목동남로 4길
# 4    강남구립 역삼푸른솔 도서관  서울   강남구  2009          서울특별시 강남구 테헤란로8길 36 (역삼동)
# ..              ...  ..   ...   ...                                ...
# 194       아리랑어린이도서관  서울   성북구  2017  서울특별시 성북구 아리랑로 75 (돈암동, 돈암코오롱하늘채)
# 198        종암동새날도서관  서울   성북구  2011                    서울 성북구 종암로 98-8
# 199       중랑숲어린이도서관  서울   중랑구  2012        서울특별시 중랑구 망우로73길 46-1 (망우동)
# 201          해오름도서관  서울   성북구  2009                         서울 성북구 돈암동
# 202        휘경어린이도서관  서울  동대문구  2014              서울특별시 동대문구 망우로18가길 38
#
#            lat         lon
# 0    37.567916  126.966862
# 1    37.493482  127.111504
# 2    37.556653  127.010213
# 3    37.508501  126.866634
# 4    37.496491  127.031845
# ..         ...         ...
# 194  37.599107  127.013795
# 198  37.598997  127.035111
# 199   37.60266  127.103881
# 201  37.597795  127.018283
# 202  37.588658  127.060623
#
# [155 rows x 7 columns]

# %% [markdown]
# # 년도 별 도서관 개수로 도서관 개수 증감 확인

# %%
print(len(lib_2017_raw))
print(len(lib_2018_raw))
print(len(lib_2019_raw))
# Out:
# 155
# 167
# 175

# %%
lib_2017_raw.head()
# Out:
#              도서관명  지역  시군구  개관년도                         주소        lat  \
# 0   4.19 혁명기념 도서관  서울  종로구  2000     서울특별시 종로구 새문안로 17 (평동)  37.567916
# 1          가락몰도서관  서울  송파구  2016   서울특별시 송파구 양재대로 932 (가락동)  37.493482
# 2           가온도서관  서울   중구  2008            서울특별시 중구 동호로14길  37.556653
# 3           갈산도서관  서울  양천구  2014          서울특별시 양천구 목동남로 4길  37.508501
# 4  강남구립 역삼푸른솔 도서관  서울  강남구  2009  서울특별시 강남구 테헤란로8길 36 (역삼동)  37.496491
#
#           lon
# 0  126.966862
# 1  127.111504
# 2  127.010213
# 3  126.866634
# 4  127.031845

# %%
# 데이터 보기 편하게 정렬
lib_2017_raw = lib_2017_raw.sort_values(by='시군구').reset_index(drop=True)
lib_2018_raw = lib_2018_raw.sort_values(by='시군구').reset_index(drop=True)
lib_2019_raw = lib_2019_raw.sort_values(by='시군구').reset_index(drop=True)

# %%
desired_columns = ['지역', '시군구', '도서관명', '개관년도', '주소', 'lat', 'lon']  # 원하는 순서대로 열 이름을 나열합니다
lib_2017_raw = lib_2017_raw.reindex(columns=desired_columns)

# %%
lib_2017_raw
# Out:
#      지역  시군구               도서관명  개관년도                             주소  \
# 0    서울  강남구              논현도서관  1997      서울특별시 강남구 학동로43길 17 (논현동)
# 1    서울  강남구             행복한도서관  2006     서울특별시 강남구 영동대로65길 24 (대치동)
# 2    서울  강남구      서울특별시교육청강남도서관  1982     서울특별시 강남구 선릉로116길 45 (삼성동)
# 3    서울  강남구             정다운도서관  2004               서울특별시 강남구 학동로67길
# 4    서울  강남구             즐거운도서관  2004  서울특별시 강남구 도곡로77길 23, 4층 (대치동)
# ..   ..  ...                ...   ...                            ...
# 150  서울   중구              가온도서관  2008                서울특별시 중구 동호로14길
# 151  서울   중구  남산타운문화체육센터 어린이도서관  2011                   서울특별시 중구 다산로
# 152  서울  중랑구          중랑구립정보도서관  1999      서울특별시 중랑구 신내로15길 197 (묵동)
# 153  서울  중랑구        중랑구립면목정보도서관  2005        서울특별시 중랑구 면목로 397 (면목동)
# 154  서울  중랑구          중랑숲어린이도서관  2012    서울특별시 중랑구 망우로73길 46-1 (망우동)
#
#            lat         lon
# 0    37.517292  127.037235
# 1    37.498425  127.076531
# 2    37.512433  127.048779
# 3    37.519207  127.046721
# 4    37.499743  127.057849
# ..         ...         ...
# 150  37.556653  127.010213
# 151  37.558725  127.012021
# 152  37.615218   127.08694
# 153  37.587359   127.08756
# 154   37.60266  127.103881
#
# [155 rows x 7 columns]

# %%
lib_2017_raw.to_excel('../data/공공도서관_구별_주소_2017.xlsx')
lib_2018_raw.to_excel('../data/공공도서관_구별_주소_2018.xlsx')
lib_2019_raw.to_excel('../data/공공도서관_구별_주소_2019.xlsx')

# %%
#lib_2017_raw.set_index('시군구', inplace=True)
# folium 쓰기 위해

# %% [markdown]
# # 구별 도서관 개수 담은 데이터프레임 만들기

# %%
lib_2017_total = lib_2017_raw.groupby('시군구').agg('count')
lib_2018_total = lib_2018_raw.groupby('시군구').agg('count')
lib_2019_total = lib_2019_raw.groupby('시군구').agg('count')
# 각 구별 도서관 개수 확인

# %%
lib_2017_total = lib_2017_total[['도서관명']] # 나머지 컬럼 drop
lib_2017_total.rename(columns = {'도서관명' : '2017'}, inplace = True) # 이름 변경
lib_2018_total = lib_2018_total[['도서관명']] # 나머지 컬럼 drop
lib_2018_total.rename(columns = {'도서관명' : '2018'}, inplace = True) # 이름 변경
lib_2019_total = lib_2019_total[['도서관명']] # 나머지 컬럼 drop
lib_2019_total.rename(columns = {'도서관명' : '2019'}, inplace = True) # 이름 변경

# %%
lib_2017_total.reset_index(inplace = True) # 인덱스 초기화
lib_2018_total.reset_index(inplace = True)
lib_2019_total.reset_index(inplace = True)

# %%
lib_2017_total.insert(0, '시도', '서울특별시') # 태블로 사용을 위한 시도 컬럼 추가
lib_2018_total.insert(0, '시도', '서울특별시')
lib_2019_total.insert(0, '시도', '서울특별시')

# %%
lib_2017_total # 각 구별 도서관 수 결과.
# Out:
#        시도   시군구  2017
# 0   서울특별시   강남구    12
# 1   서울특별시   강동구     8
# 2   서울특별시   강북구     7
# 3   서울특별시   강서구     9
# 4   서울특별시   관악구     5
# 5   서울특별시   광진구     4
# 6   서울특별시   구로구    10
# 7   서울특별시   금천구     4
# 8   서울특별시   노원구     6
# 9   서울특별시   도봉구     6
# 10  서울특별시  동대문구     4
# 11  서울특별시   동작구     4
# 12  서울특별시   마포구     5
# 13  서울특별시  서대문구     4
# 14  서울특별시   서초구     4
# 15  서울특별시   성동구     6
# 16  서울특별시   성북구    10
# 17  서울특별시   송파구    12
# 18  서울특별시   양천구     6
# 19  서울특별시  영등포구     5
# 20  서울특별시   용산구     4
# 21  서울특별시   은평구     6
# 22  서울특별시   종로구     6
# 23  서울특별시    중구     5
# 24  서울특별시   중랑구     3

# %% [markdown]
# # 각 년도별 데이터 merge

# %%
lib_years_info = lib_2017_total.merge(lib_2018_total, on = '시군구', how='inner').merge(lib_2019_total, on = '시군구', how = 'inner')
lib_years_info = lib_years_info[['시도', '시군구', '2017', '2018', '2019']]
lib_years_info
# Out:
#        시도   시군구  2017  2018  2019
# 0   서울특별시   강남구    12    13    13
# 1   서울특별시   강동구     8     8     8
# 2   서울특별시   강북구     7     7     7
# 3   서울특별시   강서구     9     9     9
# 4   서울특별시   관악구     5     5     5
# 5   서울특별시   광진구     4     4     4
# 6   서울특별시   구로구    10    10    11
# 7   서울특별시   금천구     4     4     4
# 8   서울특별시   노원구     6     8     8
# 9   서울특별시   도봉구     6     6     7
# 10  서울특별시  동대문구     4     4     5
# 11  서울특별시   동작구     4     5     5
# 12  서울특별시   마포구     5     5     5
# 13  서울특별시  서대문구     4     4     4
# 14  서울특별시   서초구     4     6     7
# 15  서울특별시   성동구     6     6     6
# 16  서울특별시   성북구    10    10    12
# 17  서울특별시   송파구    12    12    12
# 18  서울특별시   양천구     6     9     9
# 19  서울특별시  영등포구     5     5     5
# 20  서울특별시   용산구     4     4     4
# 21  서울특별시   은평구     6     7     8
# 22  서울특별시   종로구     6     7     7
# 23  서울특별시    중구     5     5     5
# 24  서울특별시   중랑구     3     4     5

# %% [markdown]
# # 각 년도별 도서관 수의 차이

# %%
lib_years_info['2017~2018'] = abs(lib_years_info['2017'] - lib_years_info['2018'])
lib_years_info['2018~2019'] = abs(lib_years_info['2018'] - lib_years_info['2019'])
lib_years_info['2017~2019'] = abs(lib_years_info['2017'] - lib_years_info['2019'])

# %%
lib_years_info
# Out:
#        시도   시군구  2017  2018  2019  2017~2018  2018~2019  2017~2019
# 0   서울특별시   강남구    12    13    13          1          0          1
# 1   서울특별시   강동구     8     8     8          0          0          0
# 2   서울특별시   강북구     7     7     7          0          0          0
# 3   서울특별시   강서구     9     9     9          0          0          0
# 4   서울특별시   관악구     5     5     5          0          0          0
# 5   서울특별시   광진구     4     4     4          0          0          0
# 6   서울특별시   구로구    10    10    11          0          1          1
# 7   서울특별시   금천구     4     4     4          0          0          0
# 8   서울특별시   노원구     6     8     8          2          0          2
# 9   서울특별시   도봉구     6     6     7          0          1          1
# 10  서울특별시  동대문구     4     4     5          0          1          1
# 11  서울특별시   동작구     4     5     5          1          0          1
# 12  서울특별시   마포구     5     5     5          0          0          0
# 13  서울특별시  서대문구     4     4     4          0          0          0
# 14  서울특별시   서초구     4     6     7          2          1          3
# 15  서울특별시   성동구     6     6     6          0          0          0
# 16  서울특별시   성북구    10    10    12          0          2          2
# 17  서울특별시   송파구    12    12    12          0          0          0
# 18  서울특별시   양천구     6     9     9          3          0          3
# 19  서울특별시  영등포구     5     5     5          0          0          0
# 20  서울특별시   용산구     4     4     4          0          0          0
# 21  서울특별시   은평구     6     7     8          1          1          2
# 22  서울특별시   종로구     6     7     7          1          0          1
# 23  서울특별시    중구     5     5     5          0          0          0
# 24  서울특별시   중랑구     3     4     5          1          1          2

# %%
sum_row = lib_years_info.sum()
new_row = pd.DataFrame([sum_row], columns=lib_years_info.columns)
lib_years_info = pd.concat([lib_years_info, new_row], ignore_index=True)

# %%
lib_years_info
# Out:
#                                                    시도  \
# 0                                               서울특별시
# 1                                               서울특별시
# 2                                               서울특별시
# 3                                               서울특별시
# 4                                               서울특별시
# 5                                               서울특별시
# 6                                               서울특별시
# 7                                               서울특별시
# 8                                               서울특별시
# 9                                               서울특별시
# 10                                              서울특별시
# 11                                              서울특별시
# 12                                              서울특별시
# 13                                              서울특별시
# 14                                              서울특별시
# 15                                              서울특별시
# 16                                              서울특별시
# 17                                              서울특별시
# 18                                              서울특별시
# 19                                              서울특별시
# 20                                              서울특별시
# 21                                              서울특별시
# 22                                              서울특별시
# 23                                              서울특별시
# 24                                              서울특별시
# 25  서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서울특별시서...
#
#                                                   시군구  2017  2018  2019  \
# 0                                                 강남구    12    13    13
# 1                                                 강동구     8     8     8
# 2                                                 강북구     7     7     7
# 3                                                 강서구     9     9     9
# 4                                                 관악구     5     5     5
# 5                                                 광진구     4     4     4
# 6                                                 구로구    10    10    11
# 7                                                 금천구     4     4     4
# 8                                                 노원구     6     8     8
# 9                                                 도봉구     6     6     7
# 10                                               동대문구     4     4     5
# 11                                                동작구     4     5     5
# 12                                                마포구     5     5     5
# 13                                               서대문구     4     4     4
# 14                                                서초구     4     6     7
# 15                                                성동구     6     6     6
# 16                                                성북구    10    10    12
# 17                                                송파구    12    12    12
# 18                                                양천구     6     9     9
# 19                                               영등포구     5     5     5
# 20                                                용산구     4     4     4
# 21                                                은평구     6     7     8
# 22                                                종로구     6     7     7
# 23                                                 중구     5     5     5
# 24                                                중랑구     3     4     5
# 25  강남구강동구강북구강서구관악구광진구구로구금천구노원구도봉구동대문구동작구마포구서대문구서초...   155   167   175
#
#     2017~2018  2018~2019  2017~2019
# 0           1          0          1
# 1           0          0          0
# 2           0          0          0
# 3           0          0          0
# 4           0          0          0
# 5           0          0          0
# 6           0          1          1
# 7           0          0          0
# 8           2          0          2
# 9           0          1          1
# 10          0          1          1
# 11          1          0          1
# 12          0          0          0
# 13          0          0          0
# 14          2          1          3
# 15          0          0          0
# 16          0          2          2
# 17          0          0          0
# 18          3          0          3
# 19          0          0          0
# 20          0          0          0
# 21          1          1          2
# 22          1          0          1
# 23          0          0          0
# 24          1          1          2
# 25         12          8         20

# %%
lib_years_info.at[25, '시도'] = '서울특별시'
lib_years_info.at[25, '시군구'] = '자치구'

# %%
lib_years_info
# Out:
#        시도   시군구  2017  2018  2019  2017~2018  2018~2019  2017~2019
# 0   서울특별시   강남구    12    13    13          1          0          1
# 1   서울특별시   강동구     8     8     8          0          0          0
# 2   서울특별시   강북구     7     7     7          0          0          0
# 3   서울특별시   강서구     9     9     9          0          0          0
# 4   서울특별시   관악구     5     5     5          0          0          0
# 5   서울특별시   광진구     4     4     4          0          0          0
# 6   서울특별시   구로구    10    10    11          0          1          1
# 7   서울특별시   금천구     4     4     4          0          0          0
# 8   서울특별시   노원구     6     8     8          2          0          2
# 9   서울특별시   도봉구     6     6     7          0          1          1
# 10  서울특별시  동대문구     4     4     5          0          1          1
# 11  서울특별시   동작구     4     5     5          1          0          1
# 12  서울특별시   마포구     5     5     5          0          0          0
# 13  서울특별시  서대문구     4     4     4          0          0          0
# 14  서울특별시   서초구     4     6     7          2          1          3
# 15  서울특별시   성동구     6     6     6          0          0          0
# 16  서울특별시   성북구    10    10    12          0          2          2
# 17  서울특별시   송파구    12    12    12          0          0          0
# 18  서울특별시   양천구     6     9     9          3          0          3
# 19  서울특별시  영등포구     5     5     5          0          0          0
# 20  서울특별시   용산구     4     4     4          0          0          0
# 21  서울특별시   은평구     6     7     8          1          1          2
# 22  서울특별시   종로구     6     7     7          1          0          1
# 23  서울특별시    중구     5     5     5          0          0          0
# 24  서울특별시   중랑구     3     4     5          1          1          2
# 25  서울특별시   자치구   155   167   175         12          8         20

# %% [markdown]
# # 태블로 사용을 위해 저장

# %%
lib_2017_total.to_excel('../data/공공도서관_구별_개수_2017.xlsx')
lib_2018_total.to_excel('../data/공공도서관_구별_개수_2018.xlsx')
lib_2019_total.to_excel('../data/공공도서관_구별_개수_2019.xlsx')
lib_years_info.to_excel('../data/공공도서관_구별_개수_total.xlsx')

# %% [markdown]
# # folium 사용을 위한 새 데이터프레임 짜기

# %%
# 수업에서 사용한 json 파일은 인덱스를 시군구로 사용해야 적용이됨.
df = lib_2017_total[['시군구', '도서관수']]
df.set_index('시군구', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 # 수업에서 사용한 json 파일은 인덱스를 시군구로 사용해야 적용이됨.
# ----> 2 df = lib_2017_total[['시군구', '도서관수']]
#       3 df.set_index('시군구', inplace = True)
#
# File ~/Desktop/myweedsgroweveryday/playdata/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Desktop/myweedsgroweveryday/playdata/lib/python3.9/site-packages/pandas/core/indexes/base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~/Desktop/myweedsgroweveryday/playdata/lib/python3.9/site-packages/pandas/core/indexes/base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['도서관수'] not in index"

# %%
geo_path = '../data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5)

map.choropleth(geo_data = geo_str,
               data = df,
               columns=[df.index, '도서관수'],
               fill_color='PuRd', #PuRd, YlGnBu
               key_on='feature.id')
map
# Out:
# /Users/jeongjinseo/Desktop/myweedsgroweveryday/playdata/lib/python3.9/site-packages/folium/folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee1996a72a14f986738f1539a37ade9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee1996a72a14f986738f1539a37ade9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee1996a72a14f986738f1539a37ade9b = L.map(
#                 &quot;map_ee1996a72a14f986738f1539a37ade9b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3302ca45c0512c88ddc9f93929c7fa0c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ee1996a72a14f986738f1539a37ade9b);
#
#
#             var choropleth_8edb68f8a5ffff6db8cb854f5015cfc9 = L.featureGroup(
#                 {}
#             ).addTo(map_ee1996a72a14f986738f1539a37ade9b);
#
#
#         function geo_json_852f319ce38e92738b7bdab1ef52504e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_852f319ce38e92738b7bdab1ef52504e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_852f319ce38e92738b7bdab1ef52504e = L.geoJson(null, {
#                 onEachFeature: geo_json_852f319ce38e92738b7bdab1ef52504e_onEachFeature,
#
#                 style: geo_json_852f319ce38e92738b7bdab1ef52504e_styler,
#         });
#
#         function geo_json_852f319ce38e92738b7bdab1ef52504e_add (data) {
#             geo_json_852f319ce38e92738b7bdab1ef52504e
#                 .addData(data)
#                 .addTo(choropleth_8edb68f8a5ffff6db8cb854f5015cfc9);
#         }
#             geo_json_852f319ce38e92738b7bdab1ef52504e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048],
